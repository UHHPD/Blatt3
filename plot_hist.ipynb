# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("histpoi.txt")

# %%
data
# Out:
# array([[ 0.       , 12.       ,  0.       ],
#        [ 1.       , 23.       ,  1.4102   ],
#        [ 2.       , 53.       ,  9.56369  ],
#        [ 3.       , 57.       , 12.7704   ],
#        [ 4.       , 47.       ,  9.18224  ],
#        [ 5.       , 19.       ,  2.6671   ],
#        [ 6.       , 17.       ,  1.517    ],
#        [ 7.       ,  4.       ,  0.208517 ],
#        [ 8.       ,  2.       ,  0.0572523],
#        [ 9.       ,  0.       ,  0.       ],
#        [10.       ,  0.       ,  0.       ]])

# %%
plt.plot(data[:, 0], data[:,1], "bo", label="data")
plt.step(data[:, 0]-0.5, data[:,2], "g", label="prediction")
plt.xlabel("goals")
plt.ylabel("matches")
plt.legend()
